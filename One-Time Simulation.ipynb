# %% [markdown]
# ### Import Relevant Libraries

# %%
import numpy as np
import pandas as pd
import random

from montecarlo import create_sp_return_generator, create_housing_return_generator, last_entry, REAsset, StockAsset, one_sim

# %matplotlib inline

# %% [markdown]
# ### Purchase condo valued at 480,000 dollars over 20-year mortgage

# %%
results, ROI = one_sim(450_000, 25, 30)
results[['Stock Asset: Market Value', 'Stock Asset: Book Value', 'Stock Asset: Accrued Cost']].plot()
results[['RE Asset: Market Value', 'RE Asset: Book Value', 'RE Asset: Accrued Cost']].plot()
print("\nROI: {}".format(ROI))
# Out:
# Stock Initial Investment: $20000
# RE Initial Investment: $450000
# RE Book Value: $450000
# RE Downpayment: $90000.0
# RE Amortization Period: 25 years
# RE Monthly Payment Due: $2476.09
#
# ROI: 0.28177743438380803

# %% [markdown]
# ### Rent and put all your savings on the S&P

# %%
results, ROI = one_sim(0, 25, 30)
results[['Stock Asset: Market Value', 'Stock Asset: Book Value', 'Stock Asset: Accrued Cost']].plot()
results[['RE Asset: Market Value', 'RE Asset: Book Value', 'RE Asset: Accrued Cost']].plot()
print("\nROI: {}".format(ROI))
# Out:
# Stock Initial Investment: $20000
# RE Initial Investment: $0
# RE Book Value: $0
# RE Downpayment: $0.0
# RE Amortization Period: 25 years
# RE Monthly Payment Due: $1100.00
#
# ROI: 0.3724088922072219
